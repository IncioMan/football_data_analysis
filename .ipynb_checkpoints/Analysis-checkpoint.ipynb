# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import requests

pd.options.mode.chained_assignment = None
pd.set_option('display.max_rows', 20)

# %% [markdown]
# ## Fetch Data

# %% [markdown]
# ### Standing

# %%
url = "http://api.football-data.org/v4/competitions/SA/standings"
headers = {"X-Auth-Token": ""}

# %%
response = requests.get(url, headers=headers)

data = response.json()

data = data['standings'][0]['table']

standing = pd.DataFrame(data)

# Extract the 'shortName' value from the 'team' dictionary
standing['team_short_name'] = standing['team'].apply(lambda x: x['shortName'])

# Drop the 'team' column
standing.drop(columns=['team'], inplace=True)

standing
# Out:
#     position  playedGames  form  won  draw  lost  points  goalsFor  \
# 0          1           27  None   23     2     2      71        64
# 1          2           27  None   15     7     5      52        42
# 2          3           27  None   16     2     9      50        47
# 3          4           27  None   14     6     7      48        44
# 4          5           27  None   14     5     8      47        35
# 5          6           27  None   13     6     8      45        44
# 6          7           27  None   17     5     5      41        45
# 7          8           27  None    9    11     7      38        37
# 8          9           27  None   10     7    10      37        32
# 9         10           27  None   10     7    10      37        33
# 10        11           27  None   10     7    10      37        29
# 11        12           27  None   10     6    11      36        35
# 12        13           27  None    9     7    11      34        32
# 13        14           27  None    6    10    11      28        24
# 14        15           27  None    6     9    12      27        24
# 15        16           27  None    6     9    12      27        31
# 16        17           27  None    5     9    13      24        23
# 17        18           27  None    4     7    16      19        22
# 18        19           27  None    3     6    18      15        16
# 19        20           27  None    1    10    16      13        22
#
#     goalsAgainst  goalDifference team_short_name
# 0             16              48          Napoli
# 1             19              23           Lazio
# 2             31              16           Inter
# 3             36               8           Milan
# 4             26               9            Roma
# 5             31              13        Atalanta
# 6             22              23        Juventus
# 7             31               6         Udinese
# 8             31               1      Fiorentina
# 9             36              -3         Bologna
# 10            33              -4          Torino
# 11            40              -5        Sassuolo
# 12            37              -5           Monza
# 13            36             -12          Empoli
# 14            32              -8           Lecce
# 15            47             -16     Salernitana
# 16            43             -20   Spezia Calcio
# 17            41             -19          Verona
# 18            44             -28       Sampdoria
# 19            49             -27       Cremonese

# %% [markdown]
# #### Data Addition

# %%
n_groups = 3

# %%
standing['team_group'] = standing.position.apply(lambda x: int(((x-1)/(20/n_groups))))
standing
# Out:
#     position  playedGames  form  won  draw  lost  points  goalsFor  \
# 0          1           27  None   23     2     2      71        64
# 1          2           27  None   15     7     5      52        42
# 2          3           27  None   16     2     9      50        47
# 3          4           27  None   14     6     7      48        44
# 4          5           27  None   14     5     8      47        35
# 5          6           27  None   13     6     8      45        44
# 6          7           27  None   17     5     5      41        45
# 7          8           27  None    9    11     7      38        37
# 8          9           27  None   10     7    10      37        32
# 9         10           27  None   10     7    10      37        33
# 10        11           27  None   10     7    10      37        29
# 11        12           27  None   10     6    11      36        35
# 12        13           27  None    9     7    11      34        32
# 13        14           27  None    6    10    11      28        24
# 14        15           27  None    6     9    12      27        24
# 15        16           27  None    6     9    12      27        31
# 16        17           27  None    5     9    13      24        23
# 17        18           27  None    4     7    16      19        22
# 18        19           27  None    3     6    18      15        16
# 19        20           27  None    1    10    16      13        22
#
#     goalsAgainst  goalDifference team_short_name  team_group
# 0             16              48          Napoli           0
# 1             19              23           Lazio           0
# 2             31              16           Inter           0
# 3             36               8           Milan           0
# 4             26               9            Roma           0
# 5             31              13        Atalanta           0
# 6             22              23        Juventus           0
# 7             31               6         Udinese           1
# 8             31               1      Fiorentina           1
# 9             36              -3         Bologna           1
# 10            33              -4          Torino           1
# 11            40              -5        Sassuolo           1
# 12            37              -5           Monza           1
# 13            36             -12          Empoli           1
# 14            32              -8           Lecce           2
# 15            47             -16     Salernitana           2
# 16            43             -20   Spezia Calcio           2
# 17            41             -19          Verona           2
# 18            44             -28       Sampdoria           2
# 19            49             -27       Cremonese           2

# %% [markdown]
# ### Results

# %%
url = "https://www.football-data.co.uk/mmz4281/2223/I1.csv"
response = requests.get(url)
file_path = './Serie_A_2022_2023.csv'

with open(file_path, "wb") as f:
    f.write(response.content)

# %% [markdown]
# ## Analysis

# %%
df = pd.read_csv(file_path)
df
# Out:
#     Div        Date   Time    HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    I1  13/08/2022  17:30       Milan    Udinese     4     2   H     2     2
# 1    I1  13/08/2022  17:30   Sampdoria   Atalanta     0     2   A     0     1
# 2    I1  13/08/2022  19:45       Lecce      Inter     1     2   A     0     1
# 3    I1  13/08/2022  19:45       Monza     Torino     1     2   A     0     1
# 4    I1  14/08/2022  17:30  Fiorentina  Cremonese     3     2   H     2     1
# ..   ..         ...    ...         ...        ...   ...   ...  ..   ...   ...
# 265  I1  19/03/2023  11:30   Sampdoria     Verona     3     1   H     2     0
# 266  I1  19/03/2023  14:00  Fiorentina      Lecce     1     0   H     1     0
# 267  I1  19/03/2023  14:00      Torino     Napoli     0     4   A     0     2
# 268  I1  19/03/2023  17:00       Lazio       Roma     1     0   H     0     0
# 269  I1  19/03/2023  19:45       Inter   Juventus     0     1   A     0     1
#
#      ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0    ...     2.16 -1.25      1.98      1.92   2.02   1.91     2.17     1.94
# 1    ...     2.24  0.75      2.07      1.83   2.11   1.82     2.13     1.87
# 2    ...     2.55  1.50      1.90      2.00   1.91   2.02     1.96     2.06
# 3    ...     1.75  0.00      1.79      2.11   1.80   2.15     1.88     2.16
# 4    ...     2.09 -1.00      2.02      1.88   2.06   1.87     2.07     1.97
# ..   ...      ...   ...       ...       ...    ...    ...      ...      ...
# 265  ...     1.54  0.00      2.14      1.77   2.17   1.79     2.17     1.85
# 266  ...     1.70 -1.00      2.02      1.77   2.13   1.80     2.16     1.87
# 267  ...     1.62  0.75      1.82      2.08   1.85   2.08     1.90     2.22
# 268  ...     1.41  0.00      2.08      1.82   2.11   1.83     2.13     1.85
# 269  ...     1.64 -0.50      2.05      1.85   2.05   1.88     2.10     1.89
#
#      AvgCAHH  AvgCAHA
# 0       2.06     1.81
# 1       2.06     1.82
# 2       1.89     1.97
# 3       1.83     2.06
# 4       1.99     1.87
# ..       ...      ...
# 265     2.08     1.81
# 266     2.07     1.81
# 267     1.81     2.07
# 268     2.08     1.81
# 269     2.04     1.84
#
# [270 rows x 105 columns]

# %% [markdown]
# ### Add giornata

# %%
df.loc[(df.HomeTeam == 'Empoli') & (df.AwayTeam == 'Cremonese'),'Date'] = '12/11/2022'
df['year'] = pd.to_datetime(df.Date, format='%d/%m/%Y').dt.year
df['month'] = pd.to_datetime(df.Date,format='%d/%m/%Y').dt.month
df['day'] = pd.to_datetime(df.Date,format='%d/%m/%Y').dt.day
df['week'] = pd.to_datetime(df.Date,format='%d/%m/%Y').dt.isocalendar().week
df['weekday'] = pd.to_datetime(df.Date,format='%d/%m/%Y').dt.weekday

# %%
df.head()
# Out:
#   Div        Date   Time    HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  I1  13/08/2022  17:30       Milan    Udinese     4     2   H     2     2
# 1  I1  13/08/2022  17:30   Sampdoria   Atalanta     0     2   A     0     1
# 2  I1  13/08/2022  19:45       Lecce      Inter     1     2   A     0     1
# 3  I1  13/08/2022  19:45       Monza     Torino     1     2   A     0     1
# 4  I1  14/08/2022  17:30  Fiorentina  Cremonese     3     2   H     2     1
#
#    ... PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  year  month  day  week  \
# 0  ...  1.91     2.17     1.94     2.06     1.81  2022      8   13    32
# 1  ...  1.82     2.13     1.87     2.06     1.82  2022      8   13    32
# 2  ...  2.02     1.96     2.06     1.89     1.97  2022      8   13    32
# 3  ...  2.15     1.88     2.16     1.83     2.06  2022      8   13    32
# 4  ...  1.87     2.07     1.97     1.99     1.87  2022      8   14    32
#
#    weekday
# 0        5
# 1        5
# 2        5
# 3        5
# 4        6
#
# [5 rows x 110 columns]

# %%
df['FTG'] = df['FTHG'] + df['FTAG']

# %%
df = df.sort_values(['year', 'month', 'day'])

# Assign sequential week numbers to blocks of days from Thursday to Wednesday
giornata = 1
curr_day = (2020,1,1,-1,-1)
infrasettimanale = False
for i, row in df.iterrows():
    if row['week'] != curr_day[3] and abs(curr_day[4] - row['weekday']) < 6: 
        giornata += 1
    if row['week'] == curr_day[3] and abs(curr_day[4] - row['weekday']) > 1: 
        giornata += 1
    curr_day = (row['year'], row['month'], row['day'], row['week'], row['weekday'])
    df.at[i, 'giornata'] = giornata

# %%
df.head()
# Out:
#   Div        Date   Time    HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  I1  13/08/2022  17:30       Milan    Udinese     4     2   H     2     2
# 1  I1  13/08/2022  17:30   Sampdoria   Atalanta     0     2   A     0     1
# 2  I1  13/08/2022  19:45       Lecce      Inter     1     2   A     0     1
# 3  I1  13/08/2022  19:45       Monza     Torino     1     2   A     0     1
# 4  I1  14/08/2022  17:30  Fiorentina  Cremonese     3     2   H     2     1
#
#    ... MaxCAHA  AvgCAHH  AvgCAHA  year  month  day  week  weekday  FTG  \
# 0  ...    1.94     2.06     1.81  2022      8   13    32        5    6
# 1  ...    1.87     2.06     1.82  2022      8   13    32        5    2
# 2  ...    2.06     1.89     1.97  2022      8   13    32        5    3
# 3  ...    2.16     1.83     2.06  2022      8   13    32        5    3
# 4  ...    1.97     1.99     1.87  2022      8   14    32        6    5
#
#    giornata
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#
# [5 rows x 112 columns]

# %%
df.tail()
# Out:
#     Div        Date   Time    HomeTeam  AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 265  I1  19/03/2023  11:30   Sampdoria    Verona     3     1   H     2     0
# 266  I1  19/03/2023  14:00  Fiorentina     Lecce     1     0   H     1     0
# 267  I1  19/03/2023  14:00      Torino    Napoli     0     4   A     0     2
# 268  I1  19/03/2023  17:00       Lazio      Roma     1     0   H     0     0
# 269  I1  19/03/2023  19:45       Inter  Juventus     0     1   A     0     1
#
#      ... MaxCAHA  AvgCAHH  AvgCAHA  year  month  day  week  weekday  FTG  \
# 265  ...    1.85     2.08     1.81  2023      3   19    11        6    4
# 266  ...    1.87     2.07     1.81  2023      3   19    11        6    1
# 267  ...    2.22     1.81     2.07  2023      3   19    11        6    4
# 268  ...    1.85     2.08     1.81  2023      3   19    11        6    1
# 269  ...    1.89     2.04     1.84  2023      3   19    11        6    1
#
#      giornata
# 265      27.0
# 266      27.0
# 267      27.0
# 268      27.0
# 269      27.0
#
# [5 rows x 112 columns]

# %% [markdown]
# ### Plot number goals over giornate

# %%
df[['giornata','FTG','FTHG','FTAG']].groupby(['giornata']).sum().FTG.plot()
# Out:
# <Axes: xlabel='giornata'>

# %% [markdown]
# ### Goals distribution over matches in each giornata

# %%
df['row_num'] = df.groupby('giornata').cumcount()
boxgoals = df[['giornata','row_num','FTG','FTHG','FTAG']].pivot(index='row_num', columns='giornata', values='FTG')

# %%
boxgoals.plot(kind='box', figsize=(12,4))
# Out:
# <Axes: >

# %% [markdown]
# ### Under/Over

# %%
df['tot_goal'] = df.FTHG + df.FTAG

# %%
tt_htg = df[['HomeTeam','tot_goal']]
tt_atg = df[['AwayTeam','tot_goal']]
tt_htg.columns = ['Team','tot_goal']
tt_htg['type'] = 'home'
tt_atg.columns = ['Team','tot_goal']
tt_atg['type'] = 'away'
df_uog = pd.concat([tt_atg,tt_htg])

fig, ax = plt.subplots(1, 3, figsize=(12, 4))
df_uog.groupby('Team').mean().sort_values('tot_goal').plot(kind='bar',  ax=ax[0])
df_uog[df_uog.type=='home'].groupby('Team').mean().sort_values('tot_goal').plot(kind='bar',  ax=ax[1])
df_uog[df_uog.type=='away'].groupby('Team').mean().sort_values('tot_goal').plot(kind='bar',  ax=ax[2])

ax[0].set_title('Total')
ax[1].set_title('Home')
ax[2].set_title('Away')
ax[0].set_ylabel('Average goals')
ax[1].set_ylabel('Average goals')
ax[2].set_ylabel('Average goals')

plt.show()
# Out:
# /tmp/ipykernel_311/2220126172.py:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_uog.groupby('Team').mean().sort_values('tot_goal').plot(kind='bar',  ax=ax[0])
# /tmp/ipykernel_311/2220126172.py:11: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_uog[df_uog.type=='home'].groupby('Team').mean().sort_values('tot_goal').plot(kind='bar',  ax=ax[1])
# /tmp/ipykernel_311/2220126172.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_uog[df_uog.type=='away'].groupby('Team').mean().sort_values('tot_goal').plot(kind='bar',  ax=ax[2])

# %% [markdown]
# ### Goal/No Goal

# %%
df['no_goal'] = (df.FTHG == 0) | (df.FTAG == 0)
df['goal'] = (df.FTHG != 0) & (df.FTAG != 0)
df['tot_goal'] = df.FTHG + df.FTAG
hng = df[['HomeTeam','no_goal','goal','tot_goal']]
hng.columns = ['Team','no_goal','goal','tot_goal']
hng['type'] = 'home'

# %%
ang = df[['AwayTeam','no_goal','goal','tot_goal']]
ang.columns = ['Team','no_goal','goal','tot_goal']
ang['type'] = 'away'

# %%
team_ng = pd.concat([hng,ang])

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 4))
team_ng[['Team','no_goal']].groupby('Team').sum().sort_values('no_goal').plot(kind='bar',  ax=ax[0])
team_ng[team_ng.type=='home'][['Team','no_goal']].groupby('Team').sum().sort_values('no_goal').plot(kind='bar',  ax=ax[1])
team_ng[team_ng.type=='away'][['Team','no_goal']].groupby('Team').sum().sort_values('no_goal').plot(kind='bar',  ax=ax[2])

ax[0].set_title('Total')
ax[1].set_title('Home')
ax[2].set_title('Away')
ax[0].set_ylabel('N° No Goal Matches')
ax[1].set_ylabel('N° No Goal Matches')
ax[2].set_ylabel('N° No Goal Matches')

plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 4))
team_ng[['Team','goal']].groupby('Team').sum().sort_values('goal').plot(kind='bar',  ax=ax[0])
team_ng[team_ng.type=='home'][['Team','goal']].groupby('Team').sum().sort_values('goal').plot(kind='bar',  ax=ax[1])
team_ng[team_ng.type=='away'][['Team','goal']].groupby('Team').sum().sort_values('goal').plot(kind='bar',  ax=ax[2])

ax[0].set_title('Total')
ax[1].set_title('Home')
ax[2].set_title('Away')
ax[0].set_ylabel('N° Goal Matches')
ax[1].set_ylabel('N° Goal Matches')
ax[2].set_ylabel('N° Goal Matches')

plt.show()

# %% [markdown]
# ## Match analysis

# %%
home_team = 'Sassuolo'
away_team = 'Torino'

# %%
df['no_goal'] = (df.FTHG == 0) | (df.FTAG == 0)
df['goal'] = (df.FTHG != 0) & (df.FTAG != 0)
df['tot_goals'] = df.FTHG + df.FTAG

# %% [markdown]
# #### Home Team

# %%
team_home_away = df[(df.AwayTeam==home_team)]
team_home_away['goal_fatti'] = team_home_away['FTAG']
team_home_away['goal_subiti'] = team_home_away['FTHG']
team_home_away['Team'] = team_home_away['AwayTeam']
team_home_away['Opponent'] = team_home_away['HomeTeam']
team_home_away['type'] = 'away'

team_home_home = df[(df.HomeTeam==home_team)]
team_home_home['goal_fatti'] = team_home_home['FTHG']
team_home_home['goal_subiti'] = team_home_home['FTAG']
team_home_home['Team'] = team_home_home['HomeTeam']
team_home_home['Opponent'] = team_home_home['AwayTeam']
team_home_home['type'] = 'home'

team_home_df = pd.concat([team_home_home[['Team','Opponent','goal_fatti','goal_subiti', 'type', 'giornata','goal','no_goal', 'tot_goals']],\
                        team_home_away[['Team','Opponent','goal_fatti','goal_subiti', 'type', 'giornata','goal','no_goal', 'tot_goals']]])
team_home_df
# Out:
#          Team     Opponent  goal_fatti  goal_subiti  type  giornata   goal  \
# 13   Sassuolo        Lecce           1            0  home       2.0  False
# 30   Sassuolo        Milan           0            0  home       4.0  False
# 56   Sassuolo      Udinese           1            3  home       6.0   True
# 76   Sassuolo  Salernitana           5            0  home       8.0  False
# 80   Sassuolo        Inter           1            2  home       9.0   True
# ..        ...          ...         ...          ...   ...       ...    ...
# 184  Sassuolo        Monza           1            1  away      19.0   True
# 195  Sassuolo        Milan           5            2  away      20.0   True
# 214  Sassuolo      Udinese           2            2  away      22.0   True
# 231  Sassuolo        Lecce           1            0  away      24.0  False
# 257  Sassuolo         Roma           4            3  away      26.0   True
#
#      no_goal  tot_goals
# 13      True          1
# 30      True          0
# 56     False          4
# 76      True          5
# 80     False          3
# ..       ...        ...
# 184    False          2
# 195    False          7
# 214    False          4
# 231     True          1
# 257    False          7
#
# [27 rows x 9 columns]

# %%
team_home_df_grp = team_home_df.merge(standing, left_on='Opponent', right_on='team_short_name')
team_home_df_grp = team_home_df_grp[team_home_df_grp.team_group == standing[standing['team_short_name']==away_team].team_group.max()]

# %% [markdown]
# ##### Goal/No Goal

# %%
team_home_df_grp[team_home_df_grp.type=='home']
# Out:
#        Team Opponent  goal_fatti  goal_subiti  type  giornata  goal  no_goal  \
# 4  Sassuolo  Udinese           1            3  home       6.0  True    False
#
#    tot_goals  position  ...  form won  draw  lost  points  goalsFor  \
# 4          4         8  ...  None   9    11     7      38        37
#
#    goalsAgainst  goalDifference  team_short_name team_group
# 4            31               6          Udinese          1
#
# [1 rows x 21 columns]

# %%
fig, ax = plt.subplots(1, 4, figsize=(12, 3))
fig.suptitle(f"{home_team}", fontsize=14, fontweight='bold')
fig.subplots_adjust(top=0.8)

(team_home_df_grp.no_goal.value_counts(normalize=True) * 100).plot(kind='bar', title='No Goal (group)', ax=ax[0], rot=0)
(team_home_df_grp[team_home_df_grp.type=='home'].no_goal.value_counts(normalize=True) * 100).plot(kind='bar', title='No Goal (group/home)', ax=ax[1], rot=0)
(team_home_df_grp[team_home_df_grp.type=='away'].no_goal.value_counts(normalize=True) * 100).plot(kind='bar', title='No Goal (group/away)', ax=ax[2], rot=0)
(team_home_df.no_goal.value_counts(normalize=True) * 100).plot(kind='bar', title='No Goal', ax=ax[3], rot=0)

plt.show()

# %% [markdown]
# ##### N° Goals

# %%
fig, ax = plt.subplots(1, 4, figsize=(12, 3))
fig.suptitle(f"{home_team}", fontsize=14, fontweight='bold')
fig.subplots_adjust(top=0.8)

(team_home_df_grp['tot_goals'].value_counts(normalize=True) * 100).sort_index().plot(kind='bar', title='N° Goals (group)', ax=ax[0], rot=0)
(team_home_df_grp[team_home_df_grp.type=='home']['tot_goals'].value_counts(normalize=True) * 100).sort_index().plot(kind='bar', title='N° Goals (group/home)', ax=ax[1], rot=0)
(team_home_df_grp[team_home_df_grp.type=='away']['tot_goals'].value_counts(normalize=True) * 100).sort_index().plot(kind='bar', title='N° Goals (group/away)', ax=ax[2], rot=0)
(team_home_df['tot_goals'].value_counts(normalize=True) * 100).sort_index().plot(kind='bar', title='N° Goals', ax=ax[3], rot=0)

plt.show()

# %% [markdown]
# #### Away Team

# %%
team_away_away = df[(df.AwayTeam==away_team)]
team_away_away['goal_fatti'] = team_away_away['FTAG']
team_away_away['goal_subiti'] = team_away_away['FTHG']
team_away_away['Team'] = team_away_away['AwayTeam']
team_away_away['Opponent'] = team_away_away['HomeTeam']
team_away_away['type'] = 'away'

team_away_home = df[(df.HomeTeam==away_team)]
team_away_home['goal_fatti'] = team_away_home['FTHG']
team_away_home['goal_subiti'] = team_away_home['FTAG']
team_away_home['Team'] = team_away_home['HomeTeam']
team_away_home['Opponent'] = team_away_home['AwayTeam']
team_away_home['type'] = 'home'

team_away_df = pd.concat([team_away_home[['Team','Opponent','goal_fatti','goal_subiti', 'type', 'giornata','goal','no_goal','tot_goals']],\
                        team_away_away[['Team','Opponent','goal_fatti','goal_subiti', 'type', 'giornata','goal','no_goal','tot_goals']]])
team_away_df
# Out:
#        Team    Opponent  goal_fatti  goal_subiti  type  giornata   goal  \
# 10   Torino       Lazio           0            0  home       2.0  False
# 49   Torino       Lecce           1            0  home       5.0  False
# 63   Torino    Sassuolo           0            1  home       7.0  False
# 83   Torino      Empoli           1            1  home       9.0   True
# 91   Torino    Juventus           0            1  home      10.0  False
# ..      ...         ...         ...          ...   ...       ...    ...
# 182  Torino  Fiorentina           1            0  away      19.0  False
# 192  Torino      Empoli           2            2  away      20.0   True
# 210  Torino       Milan           0            1  away      22.0  False
# 239  Torino    Juventus           2            4  away      24.0   True
# 254  Torino       Lecce           2            0  away      26.0  False
#
#      no_goal  tot_goals
# 10      True          0
# 49      True          1
# 63      True          1
# 83     False          2
# 91      True          1
# ..       ...        ...
# 182     True          1
# 192    False          4
# 210     True          1
# 239    False          6
# 254     True          2
#
# [27 rows x 9 columns]

# %%
team_away_df_grp = team_away_df.merge(standing, left_on='Opponent', right_on='team_short_name')
team_away_df_grp[team_away_df_grp.team_group == standing[standing['team_short_name']==home_team].team_group.max()]
# Out:
#       Team    Opponent  goal_fatti  goal_subiti  type  giornata   goal  \
# 3   Torino    Sassuolo           0            1  home       7.0  False
# 4   Torino      Empoli           1            1  home       9.0   True
# 5   Torino      Empoli           2            2  away      20.0   True
# 12  Torino     Udinese           1            0  home      21.0  False
# 13  Torino     Udinese           2            1  away      11.0   True
# 16  Torino     Bologna           1            0  home      25.0  False
# 17  Torino     Bologna           1            2  away      13.0   True
# 20  Torino       Monza           2            1  away       1.0   True
# 25  Torino  Fiorentina           1            0  away      19.0  False
#
#     no_goal  tot_goals  position  ...  form won  draw  lost  points  goalsFor  \
# 3      True          1        12  ...  None  10     6    11      36        35
# 4     False          2        14  ...  None   6    10    11      28        24
# 5     False          4        14  ...  None   6    10    11      28        24
# 12     True          1         8  ...  None   9    11     7      38        37
# 13    False          3         8  ...  None   9    11     7      38        37
# 16     True          1        10  ...  None  10     7    10      37        33
# 17    False          3        10  ...  None  10     7    10      37        33
# 20    False          3        13  ...  None   9     7    11      34        32
# 25     True          1         9  ...  None  10     7    10      37        32
#
#     goalsAgainst  goalDifference  team_short_name team_group
# 3             40              -5         Sassuolo          1
# 4             36             -12           Empoli          1
# 5             36             -12           Empoli          1
# 12            31               6          Udinese          1
# 13            31               6          Udinese          1
# 16            36              -3          Bologna          1
# 17            36              -3          Bologna          1
# 20            37              -5            Monza          1
# 25            31               1       Fiorentina          1
#
# [9 rows x 21 columns]

# %% [markdown]
# ##### Goal/No Goal

# %%
fig, ax = plt.subplots(1, 4, figsize=(12, 3))
fig.suptitle(f"{away_team}", fontsize=14, fontweight='bold')
fig.subplots_adjust(top=0.8)

(team_away_df_grp.no_goal.value_counts(normalize=True) * 100).plot(kind='bar', title='No Goal (group)', ax=ax[0], rot=0)
(team_away_df_grp[team_away_df_grp.type=='home'].no_goal.value_counts(normalize=True) * 100).plot(kind='bar', title='No Goal (group/home)', ax=ax[1], rot=0)
(team_away_df_grp[team_away_df_grp.type=='away'].no_goal.value_counts(normalize=True) * 100).plot(kind='bar', title='No Goal (group/away)', ax=ax[2], rot=0)
(team_away_df.no_goal.value_counts(normalize=True) * 100).plot(kind='bar', title='No Goal', ax=ax[3], rot=0)

plt.show()

# %% [markdown]
# ##### N° Goals

# %%
fig, ax = plt.subplots(1, 4, figsize=(12, 3))
fig.suptitle(f"{away_team}", fontsize=14, fontweight='bold')
fig.subplots_adjust(top=0.8)

(team_away_df_grp['tot_goals'].value_counts(normalize=True) * 100).sort_index().plot(kind='bar', title='N° Goals (group)', ax=ax[0], rot=0)
(team_away_df_grp[team_away_df_grp.type=='home']['tot_goals'].value_counts(normalize=True) * 100).sort_index().plot(kind='bar', title='N° Goals (group/home)', ax=ax[1], rot=0)
(team_away_df_grp[team_away_df_grp.type=='away']['tot_goals'].value_counts(normalize=True) * 100).sort_index().plot(kind='bar', title='N° Goals (group/away)', ax=ax[2], rot=0)
(team_away_df['tot_goals'].value_counts(normalize=True) * 100).sort_index().plot(kind='bar', title='N° Goals', ax=ax[3], rot=0)

plt.show()

# %% [markdown]
# ### Number of Goals

# %%
df_tt = pd.concat([home_sm, away_sm])
df_tt['row_num'] = df_tt.groupby('type').cumcount()
field = 'goal_subiti'
df_tt.pivot(index='row_num',columns='type',values=field).plot(kind='line', figsize=(12,4), title=team, ylabel=field)
# Out:
# <Axes: title={'center': 'Inter'}, xlabel='row_num', ylabel='goal_subiti'>

# %%
df_tt = pd.concat([home_sm, away_sm])
df_tt['row_num'] = df_tt.groupby('type').cumcount()
field = 'goal_fatti'
df_tt.pivot(index='row_num',columns='type',values=field).plot(kind='line', figsize=(12,4), title=team, ylabel=field)
# Out:
# <Axes: title={'center': 'Inter'}, xlabel='row_num', ylabel='goal_fatti'>
