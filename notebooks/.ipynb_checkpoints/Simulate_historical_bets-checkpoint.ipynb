# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import requests
import os
import numpy as np
from math import floor
import seaborn as sn

pd.options.mode.chained_assignment = None
pd.set_option('display.max_rows', 200)

# %% [markdown]
# #### Helper functions

# %%
def confusion_matrix(df: pd.DataFrame, col1: str, col2: str):
    """
    Given a dataframe with at least
    two categorical columns, create a 
    confusion matrix of the count of the columns
    cross-counts
    
    use like:
    
    >>> confusion_matrix(test_df, 'actual_label', 'predicted_label')
    """
    return (
            df
            .groupby([col1, col2])
            .size()
            .unstack(fill_value=0)
            )

# %% [markdown]
# ## Load Statistics

# %%
matches_df = pd.read_csv('../data/outputs/matches.csv')
matches_df.head(2)
# Out:
#    main_team opponent_team  goal_fatti  no_goal   goal  tot_goals
# 0      Milan       Udinese           4    False   True          6  \
# 1  Sampdoria      Atalanta           0     True  False          2
#
#    goal_subiti away_home result  team_has_scored  ...  form won  draw lost
# 0            2      home    Win             True  ...   NaN   9    12    8  \
# 1            2      home   Loss            False  ...   NaN  14     6    9
#
#    points  goalsFor goalsAgainst  goalDifference  team_short_name  team_group
# 0      39        39           36               3          Udinese           1
# 1      48        47           34              13         Atalanta           0
#
# [2 rows x 26 columns]

# %%
standings_df = pd.read_csv('../data/outputs/standings.csv')
standings_df.head(2)
# Out:
#    position  playedGames form  won  draw  lost  points  goalsFor
# 0         1           30  NaN   24     3     3      75        66  \
# 1         2           30  NaN   18     7     5      61        49
#
#    goalsAgainst  goalDifference team_short_name  team_group competition
# 0            21              45          Napoli           0     Serie A
# 1            20              29           Lazio           0     Serie A

# %%
no_goal_group_hist = pd.read_csv('../data/outputs/simulate_historical/no_goal_group.csv')
no_goal_group_hist['next_giornata'] = no_goal_group_hist['curr_giornata'] + 1
no_goal_group_hist.tail(2)
# Out:
#       n_matches main_team team_group     competition  no_goal
# 9267         10    Wolves          2  Premier League        5  \
# 9268         30    Wolves        all  Premier League       18
#
#       no_goal_streak_weighted  goal_streak_weighted  tot_giornata
# 9267                     59.0                  98.0         157.0  \
# 9268                    252.0                 214.0         466.0
#
#       no_goal_streak_weighted_ratio  goal_streak_weighted_ratio
# 9267                       0.375796                    0.624204  \
# 9268                       0.540773                    0.459227
#
#       no_goal_ratio  goal_ratio  curr_giornata  next_giornata
# 9267            0.5         0.5             31             32
# 9268            0.6         0.4             31             32

# %% [markdown]
# #### Rebuild matches to use later

# %%
hh = matches_df.rename(columns={'goal_fatti':'home_team_goal',
                          'goal_subiti':'away_team_goal',
                          'team_group':'away_team_group'})\
                [['main_team','opponent_team','away_home', 'competition',
                  'no_goal','home_team_goal','away_team_goal',
                  'giornata','away_team_group']]
aa = matches_df.rename(columns={'team_group':'home_team_group'})\
                    [['main_team','opponent_team',
                      'away_home','home_team_group']]
tt_matches_df = hh.merge(aa,\
                 left_on=['main_team','opponent_team'],\
                 right_on=['opponent_team','main_team'])
ttt_matches_df = tt_matches_df[(tt_matches_df.away_home_x=='home')&(tt_matches_df.away_home_y=='away')]
tttt_matches_df = ttt_matches_df.rename(columns={
                                'main_team_x':'home_team',
                                'opponent_team_x':'away_team',
                                'away_home_x': 'away_home'})\
                .drop(columns=['away_home_y','main_team_y','opponent_team_y'], errors='ignore')
tttt_matches_df[['away_team_group','home_team_group']] = tttt_matches_df[['away_team_group','home_team_group']].astype(str)
matches = tttt_matches_df
matches.head()
# Out:
#      home_team  away_team away_home competition  no_goal  home_team_goal
# 1        Milan    Udinese      home     Serie A    False               4  \
# 5    Sampdoria   Atalanta      home     Serie A     True               0
# 9        Lecce      Inter      home     Serie A    False               1
# 12       Monza     Torino      home     Serie A    False               1
# 14  Fiorentina  Cremonese      home     Serie A    False               3
#
#     away_team_goal  giornata away_team_group home_team_group
# 1                2       1.0               1               0
# 5                2       1.0               0               2
# 9                2       1.0               0               2
# 12               2       1.0               1               1
# 14               2       1.0               2               1

# %%
ngg = no_goal_group_hist[['n_matches', 'main_team', 'team_group', 'competition',
       'no_goal_streak_weighted_ratio', 'goal_streak_weighted_ratio',
       'no_goal_ratio', 'goal_ratio', 'next_giornata']]

dd = matches.merge(ngg,
                    left_on=['home_team','away_team_group','giornata'],
                    right_on=['main_team','team_group','next_giornata'])\
            .merge(ngg,
                    left_on=['away_team','home_team_group','giornata'],
                    right_on=['main_team','team_group','next_giornata'])

# %%
dd['no_goal_streak_weighted_ratio'] = \
        dd['no_goal_streak_weighted_ratio_x'] + dd['no_goal_streak_weighted_ratio_y']
dd['no_goal_ratio'] = \
        dd['no_goal_ratio_x'] + dd['no_goal_ratio_y']
dd['max_no_goal_streak_weighted_ratio'] = dd.apply(lambda row: \
                                               max(row['no_goal_streak_weighted_ratio_x'], 
                                                   row['no_goal_streak_weighted_ratio_y']), axis=1)
dd['max_no_goal_ratio'] = dd.apply(lambda row: \
                                               max(row['no_goal_ratio_x'], 
                                                   row['no_goal_ratio_y']), axis=1)
dd['competition'] = dd['competition_x']
dd = dd[['home_team', 'away_team', 'competition', 'away_home', 'giornata',
        'no_goal', 'home_team_goal', 'away_team_goal',
       'no_goal_streak_weighted_ratio_x',
       'no_goal_ratio_x',
       'no_goal_streak_weighted_ratio_y',
       'no_goal_ratio_y', 'goal_ratio_y',
       'no_goal_streak_weighted_ratio',
        'no_goal_ratio','max_no_goal_streak_weighted_ratio','max_no_goal_ratio']]
dd.head()
# Out:
#   home_team away_team competition away_home  giornata  no_goal
# 0     Milan   Bologna     Serie A      home       3.0     True  \
# 1    Spezia  Sassuolo     Serie A      home       3.0    False
# 2    Verona  Atalanta     Serie A      home       3.0     True
# 3     Lecce    Empoli     Serie A      home       3.0    False
# 4  Sassuolo     Milan     Serie A      home       4.0     True
#
#    home_team_goal  away_team_goal  no_goal_streak_weighted_ratio_x
# 0               2               0                              0.0  \
# 1               2               2                              1.0
# 2               0               1                              0.0
# 3               1               1                              1.0
# 4               0               0                              1.0
#
#    no_goal_ratio_x  no_goal_streak_weighted_ratio_y  no_goal_ratio_y
# 0              0.0                             0.00              0.0  \
# 1              1.0                             1.00              1.0
# 2              0.0                             1.00              1.0
# 3              1.0                             1.00              1.0
# 4              1.0                             0.75              0.5
#
#    goal_ratio_y  no_goal_streak_weighted_ratio  no_goal_ratio
# 0           1.0                           0.00            0.0  \
# 1           0.0                           2.00            2.0
# 2           0.0                           1.00            1.0
# 3           0.0                           2.00            2.0
# 4           0.5                           1.75            1.5
#
#    max_no_goal_streak_weighted_ratio  max_no_goal_ratio
# 0                                0.0                0.0
# 1                                1.0                1.0
# 2                                1.0                1.0
# 3                                1.0                1.0
# 4                                1.0                1.0

# %%
thresholds = []
competitions = []
correctness =[]
correctness_str =[]
correctness_max =[]
correctness_max_str =[]
n_guesses =[]
n_guesses_str =[]
n_guesses_max =[]
n_guesses_max_str =[]
after_x_matches =[]
i = 0
for after_x_match in [0, 10, 15, 20, 25]:
    for comp in ['Serie A','Bundesliga','Premier League','La Liga']:
        i = 0
        while i < 2:
            tt = dd[dd.competition==comp].copy()
            tt = tt[tt.giornata > after_x_match]
            tt['no_goal_from_simple_ratio'] = tt.no_goal_ratio > i
            tt['no_goal_from_streak_ratio'] = tt.no_goal_streak_weighted_ratio > i
            tt['no_goal_from_max_simple_ratio'] = tt.max_no_goal_streak_weighted_ratio > i
            tt['no_goal_from_max_streak_ratio'] = tt.max_no_goal_ratio > i
            try:
                corr = tt[tt.no_goal_from_simple_ratio].no_goal.value_counts(normalize=True)[True]
            except Exception as e:
                corr = 0   
            try:
                corr_str = tt[tt.no_goal_from_streak_ratio].no_goal.value_counts(normalize=True)[True]
            except:
                corr_str = 0
            try:
                corr_max = tt[tt.no_goal_from_max_simple_ratio].no_goal.value_counts(normalize=True)[True]
            except:
                corr_max = 0
            try:
                corr_max_str = tt[tt.no_goal_from_max_streak_ratio].no_goal.value_counts(normalize=True)[True]
            except:
                corr_max_str = 0
            after_x_matches.append(after_x_match)
            n_guesses.append(len(tt[tt.no_goal_from_simple_ratio])*corr)
            n_guesses_str.append(len(tt[tt.no_goal_from_streak_ratio])*corr_str)
            n_guesses_max.append(len(tt[tt.no_goal_from_max_simple_ratio])*corr_max)
            n_guesses_max_str.append(len(tt[tt.no_goal_from_max_streak_ratio])*corr_max_str)
            competitions.append(comp)
            correctness.append(corr)
            correctness_str.append(corr_str)
            correctness_max.append(corr_max)
            correctness_max_str.append(corr_max_str)
            thresholds.append(i)
            i = i + 0.1

# %%
results = pd.DataFrame([thresholds, correctness, correctness_str, correctness_max, correctness_max_str,
                        competitions, n_guesses, n_guesses_str, n_guesses_max, n_guesses_max_str, after_x_matches]).T
results.columns = ['threshold','corr_simple','corr_streak', 'correctness_max', 'correctness_max_str',
                   'competition','n_guesses','n_guesses_str','n_guesses_max','n_guesses_str_max','after_x_matches']
results
# Out:
#     threshold corr_simple corr_streak correctness_max correctness_max_str
# 0           0    0.520833    0.520833        0.520833            0.520833  \
# 1         0.1    0.520833    0.520833        0.520833            0.520833
# 2         0.2    0.520833    0.516807        0.514768            0.523013
# 3         0.3    0.518828    0.519313        0.513393            0.514894
# 4         0.4    0.512931    0.511111             0.5            0.495327
# ..        ...         ...         ...             ...                 ...
# 395       1.5         1.0    0.666667               0                   0
# 396       1.6         1.0           0               0                   0
# 397       1.7           0           0               0                   0
# 398       1.8           0           0               0                   0
# 399       1.9           0           0               0                   0
#
#     competition n_guesses n_guesses_str n_guesses_max n_guesses_str_max
# 0       Serie A     125.0         125.0         125.0             125.0  \
# 1       Serie A     125.0         125.0         125.0             125.0
# 2       Serie A     125.0         123.0         122.0             125.0
# 3       Serie A     124.0         121.0         115.0             121.0
# 4       Serie A     119.0         115.0         102.0             106.0
# ..          ...       ...           ...           ...               ...
# 395     La Liga       1.0           2.0             0                 0
# 396     La Liga       1.0             0             0                 0
# 397     La Liga         0             0             0                 0
# 398     La Liga         0             0             0                 0
# 399     La Liga         0             0             0                 0
#
#     after_x_matches
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 395              25
# 396              25
# 397              25
# 398              25
# 399              25
#
# [400 rows x 11 columns]

# %%
results[results.after_x_matches == 25].groupby('competition').max()
# Out:
#                threshold corr_simple corr_streak correctness_max
# competition
# Bundesliga           1.9         0.5    0.666667             0.5  \
# La Liga              1.9         1.0    0.666667        0.857143
# Premier League       1.9         1.0         1.0             0.7
# Serie A              1.9    0.555556    0.535714             0.5
#
#                correctness_max_str n_guesses n_guesses_str n_guesses_max
# competition
# Bundesliga                0.444444       8.0           8.0           8.0  \
# La Liga                   0.666667      19.0          19.0          19.0
# Premier League            0.692308      22.0          22.0          22.0
# Serie A                   0.571429      20.0          20.0          20.0
#
#                n_guesses_str_max after_x_matches
# competition
# Bundesliga                   8.0              25
# La Liga                     19.0              25
# Premier League              22.0              25
# Serie A                     20.0              25

# %%
results[(results.competition == 'Bundesliga')&(results.corr_streak>0.65)&(results.after_x_matches == 25)]
# Out:
#     threshold corr_simple corr_streak correctness_max correctness_max_str
# 350       1.0         0.5    0.666667               0                   0  \
#
#     competition n_guesses n_guesses_str n_guesses_max n_guesses_str_max
# 350  Bundesliga       1.0           2.0             0                 0  \
#
#     after_x_matches
# 350              25

# %%
results[(results.competition == 'Premier League')&(results.corr_streak>0.75)&(results.after_x_matches == 25)]
# Out:
#     threshold corr_simple corr_streak correctness_max correctness_max_str
# 373       1.3        0.75    0.818182               0                   0  \
# 374       1.4         1.0    0.857143               0                   0
# 376       1.6           0         1.0               0                   0
# 377       1.7           0         1.0               0                   0
#
#         competition n_guesses n_guesses_str n_guesses_max n_guesses_str_max
# 373  Premier League       3.0           9.0             0                 0  \
# 374  Premier League       3.0           6.0             0                 0
# 376  Premier League         0           2.0             0                 0
# 377  Premier League         0           1.0             0                 0
#
#     after_x_matches
# 373              25
# 374              25
# 376              25
# 377              25

# %%
results[(results.competition == 'Premier League')&(results.corr_simple>0.75)&(results.after_x_matches == 25)]

# %%
results[(results.competition == 'La Liga')&(results.correctness_max>0.75)&(results.after_x_matches == 25)]
# Out:
#     threshold corr_simple corr_streak correctness_max correctness_max_str
# 388       0.8    0.529412    0.533333        0.857143               0.625  \
#
#     competition n_guesses n_guesses_str n_guesses_max n_guesses_str_max
# 388     La Liga      18.0          16.0           6.0               5.0  \
#
#     after_x_matches
# 388              25

# %%
results[(results.competition == 'Serie A')&(results.correctness_max_str>0.5)&(results.after_x_matches == 25)]
# Out:
#     threshold corr_simple corr_streak correctness_max correctness_max_str
# 324       0.4         0.5         0.5        0.487179            0.512821  \
# 327       0.7         0.5    0.487179             0.5            0.571429
#
#     competition n_guesses n_guesses_str n_guesses_max n_guesses_str_max
# 324     Serie A      20.0          20.0          19.0              20.0  \
# 327     Serie A      19.0          19.0           7.0               4.0
#
#     after_x_matches
# 324              25
# 327              25

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 3), sharey=True)
plt.subplots_adjust(hspace=0.6, wspace=0.2)
fig.suptitle(f"No Goal", fontsize=14, fontweight='bold')
plt.subplots_adjust(top=0.8)

results.corr_simple.plot(kind='line', title='Simple ratio', ax=axes[0])
results.corr_streak.plot(kind='line', ax=axes[1])
plt.show()

# %%
dd.no_goal_streak_weighted_ratio.quantile(0.9)
# Out:
# 1.4577336641852772

# %%
dd.no_goal_ratio.quantile(0.9)
# Out:
# 1.3333333333333333

# %%
dd.no_goal_streak_weighted_ratio.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
dd.no_goal_ratio.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 3), sharey=True)
plt.subplots_adjust(hspace=0.6, wspace=0.2)
fig.suptitle(f"No Goal", fontsize=14, fontweight='bold')
plt.subplots_adjust(top=0.8)

sn.set(font_scale=1) # for label size
sn.heatmap(confusion_matrix(dd, 'no_goal','no_goal_from_simple_ratio'), annot=True, annot_kws={"size": 16}, ax=axes[0]) # font size
sn.heatmap(confusion_matrix(dd, 'no_goal','no_goal_from_streak_ratio'), annot=True, annot_kws={"size": 16}, ax=axes[1]) # font size
plt.show()
